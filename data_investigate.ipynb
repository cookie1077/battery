# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

data_path = "../Raw Data/#1/LR1865SZ_cycles210121_001_1.xlsx"
print(os.getcwd())

data = pd.read_excel(data_path)
data
# Out:
# /Users/chaeyeonwoo/Documents/커리어/M.IN.D Lab/Experiments/Code_for_intern
#         Data_Point Test_Time(s)  Current(A)  Capacity(Ah)  Voltage(V)  \
# 0                1     00:00:00         0.0         0.000      4.1850
# 1                2     00:00:01         0.0         0.000      4.1850
# 2                3     00:00:02         0.0         0.000      4.1850
# 3                4     00:00:03         0.0         0.000      4.1859
# 4                5     00:00:04         0.0         0.000      4.1862
# ...            ...          ...         ...           ...         ...
# 259013      259014   3-00:19:48         0.0         1.197      3.9853
# 259014      259015   3-00:19:49         0.0         1.197      3.9847
# 259015      259016   3-00:19:50         0.0         1.197      3.9847
# 259016      259017   3-00:19:51         0.0         1.197      3.9859
# 259017      259018   3-00:19:52         0.0         1.197      3.9859
#
# ...

# %% [markdown]
# # Voltage

# %%
cycles = [1,2,3,4,5]

voltage = data['Voltage(V)'][data["Cycle_Index"].isin(cycles)]

plt.plot(voltage)

# %%
cycles = [3]

voltage = data['Voltage(V)'][data["Cycle_Index"].isin(cycles)]

plt.plot(voltage)

# %% [markdown]
# # Current

# %%
#cycles = [1,2,3,4,5]

current = data["Current(A)"]#[data["Cycle_Index"].isin(cycles)]

plt.plot(current)

# %%
cycles = [3]

current = data["Current(A)"][data["Cycle_Index"].isin(cycles)]

plt.plot(current)

# %% [markdown]
# # Capacity

# %%
capacity = data['Capacity(Ah)'] 

plt.figure(figsize = (20, 5))
plt.plot(capacity)

# %%
cycles = [1,2,3,4,5]

capacity = data['Capacity(Ah)'][data["Cycle_Index"].isin(cycles)]

plt.plot(capacity)

# %%
cycles = [3]

capacity = data['Capacity(Ah)'][data["Cycle_Index"].isin(cycles)]

plt.plot(capacity)

# %%
import torch
data_path = "../Code_for_intern/dataset_f3/"

test_list = ["dataset_cell_#68", "dataset_cell_#3", "dataset_cell_#7", "dataset_cell_#25", "dataset_cell_#28", "dataset_cell_#30",
             "dataset_cell_#31", "dataset_cell_#33", "dataset_cell_#54", "dataset_cell_#70",
             "dataset_cell_#71", "dataset_cell_#76"]

for file_name in test_list:
    test_data = torch.load(data_path + file_name)
    print(test_data)
# Out:
# tensor([[[ 4.1775e+00, -6.0000e-04],
#          [ 4.1769e+00,  0.0000e+00],
#          [ 4.1769e+00,  0.0000e+00],
#          ...,
#          [ 4.1769e+00,  0.0000e+00],
#          [ 4.1769e+00,  0.0000e+00],
#          [ 4.1769e+00,  0.0000e+00]],
#
#         [[ 4.2001e+00, -1.3980e-01],
#          [ 4.0603e+00,  0.0000e+00],
#          [ 4.0603e+00, -6.5000e-03],
#          ...,
#          [ 4.0417e+00, -1.2000e-03],
#          [ 4.0405e+00, -1.3000e-03],
#          [ 4.0392e+00, -2.1000e-03]],
#
#         [[ 4.2001e+00, -1.4470e-01],
#          [ 4.0554e+00, -1.3000e-03],
#          [ 4.0541e+00, -3.7000e-03],
#          ...,
#          [ 4.0361e+00, -1.8000e-03],
#          [ 4.0343e+00, -2.5000e-03],
#          [ 4.0318e+00, -1.9000e-03]],
#
#         ...,
#
#         [[ 4.2001e+00, -7.0900e-02],
#          [ 4.1292e+00, -1.3000e-03],
#          [ 4.1279e+00, -8.0000e-03],
#          ...,
#          [ 4.1099e+00, -1.8000e-03],
#          [ 4.1081e+00, -1.3000e-03],
# ...
